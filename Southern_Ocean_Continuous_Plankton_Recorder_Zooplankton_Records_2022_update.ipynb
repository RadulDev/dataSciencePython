# %% [markdown]
# <a href="https://colab.research.google.com/github/RadulDev/dataSciencePython/blob/main/Southern_Ocean_Continuous_Plankton_Recorder_Zooplankton_Records_2022_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/AADC-00099_23June2022.csv')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (306,307,308,309) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Tow_Number Ship_Code   Time         Date    Month  Year   Season  \
# 0             1.0        AA  10:20  12-Jan-1991  January  1991  1990-91
# 1             1.0        AA  10:43  12-Jan-1991  January  1991  1990-91
# 2             1.0        AA  11:06  12-Jan-1991  January  1991  1990-91
# 3             1.0        AA  11:30  12-Jan-1991  January  1991  1990-91
# 4             1.0        AA  11:53  12-Jan-1991  January  1991  1990-91
# ...           ...       ...    ...          ...      ...   ...      ...
# 53514      1121.0        IN  08:46  22-Mar-2021    March  2021  2020-21
# 53515      1121.0        IN  09:18  22-Mar-2021    March  2021  2020-21
# 53516      1121.0        IN  09:49  22-Mar-2021    March  2021  2020-21
# ...

# %%
df['Year'].unique()
# Out:
# array([1991, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
df.columns()
# Out:
# Index(['Tow_Number', 'Ship_Code', 'Time', 'Date', 'Month', 'Year', 'Season',
#        'Latitude', 'Longitude', 'Segment_No.',
#        ...
#        'Vanadis longissima', 'Vibilia antarctica', 'Vibilia armata',
#        'Vibilia sp.', 'Total abundance', 'Phytoplankton_Colour_Index',
#        'Fluorescence', 'Salinity', 'Water_Temperature',
#        'Photosynthetically_Active_Radiation'],
#       dtype='object', length=311)
